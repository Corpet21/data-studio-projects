# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("biden_fb_geocodio.csv")

# %%
df["properties.headline"] = df["County"] + ", " + df["State"] + ": " +  df["guests"].map(str) + np.where(df["guests"]>1, ' guests', ' guest')

# %%
df["properties.articles"] = df["description"]+ ", " + df["location"]

# %%
df["properties.color"] = "#61c9bf"

# %%
def set_range(x):
    if x in range(0, 10) :
        return 5
    elif x in range(10, 50):
        return 10 
    elif x in range(50, 100):
        return 15
    elif x in range(100, 200):
        return 20
    else:
        return 30

# %%
df["properties.radius"] = df.guests.apply(set_range)

# %%
df.head()
# Out:
#      date                                        description  guests state  \
# 0  JUN 29                Meet and Greet with Dr. Jill Biden       37    IA
# 1   JUL 3   Waterloo, IA: Community Event with Joe and Ji...      31    IA
# 2   JUL 4     March with Joe and Jill Biden in the Independe       2    IA
# 3  JUN 29                Meet and Greet with Dr. Jill Biden       37    IA
# 4  JUN 28                Meet and Greet with Dr. Jill Biden       41    IA
#
#                                             location   Latitude  Longitude  \
# 0  Ames Public Library, Rotary Room 515 Douglas A...  42.037879 -93.600254
# 1                        UAW Local 838, Waterloo, IA  42.441117 -92.339209
# 2                  209 5th Ave. NE, Independence, IA  42.469864 -91.890063
# 3  Ames Public Library, Rotary Room 515 Douglas A...  42.037879 -93.600254
# 4  State Historical Museum of Iowa, 600 E. Locust...  41.672687 -93.572173
#
#    Accuracy Score Accuracy Type  Number  ...          City State  \
# 0               1         place     NaN  ...          Ames    IA
# 1               1         place     NaN  ...      Waterloo    IA
# 2               1       rooftop   209.0  ...  Independence    IA
# 3               1         place     NaN  ...          Ames    IA
# 4               1         place     NaN  ...    Des Moines    IA
#
#               County    Zip  Country  \
# 0       Story County  50010       US
# 1  Black Hawk County  50701       US
# 2    Buchanan County  50644       US
# 3       Story County  50010       US
# 4        Polk County  50301       US
#
#                                           Source  \
# 0  TIGER/Line® dataset from the US Census Bureau
# 1  TIGER/Line® dataset from the US Census Bureau
# 2                                       Buchanan
# 3  TIGER/Line® dataset from the US Census Bureau
# 4  TIGER/Line® dataset from the US Census Bureau
#
#                 properties.headline  \
# 0       Story County, IA: 37 guests
# 1  Black Hawk County, IA: 31 guests
# 2     Buchanan County, IA: 2 guests
# 3       Story County, IA: 37 guests
# 4        Polk County, IA: 41 guests
#
#                                  properties.articles properties.color  \
# 0   Meet and Greet with Dr. Jill Biden , Ames Pub...          #61c9bf
# 1   Waterloo, IA: Community Event with Joe and Ji...          #61c9bf
# 2   March with Joe and Jill Biden in the Independ...          #61c9bf
# 3   Meet and Greet with Dr. Jill Biden , Ames Pub...          #61c9bf
# 4   Meet and Greet with Dr. Jill Biden , State Hi...          #61c9bf
#
#   properties.radius
# 0                10
# 1                10
# 2                 5
# 3                10
# 4                10
#
# [5 rows x 21 columns]

# %%
df["geometry.coordinates"] = list(zip(df.Longitude, df.Latitude))

# %%
df["geometry.type"] = 'Point'

# %%
df["candidate"] = "Biden"

# %%
df.to_csv("biden_final.csv")
